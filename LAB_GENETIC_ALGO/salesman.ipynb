# %%
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# INSPIRATION FROM THE FOLLOWING BLOG
#
# https://medium.com/aimonks/traveling-salesman-problem-tsp-using-genetic-algorithm-fea640713758
#
# https://stackoverflow.com/questions/50489450/genetic-algorithm-ordered-crossover-in-python
#
# https://mat.uab.cat/~alseda/MasterOpt/GeneticOperations.pdf
#
# We tried implementing some sort of ordered crossover, the results are not great...
#
# -> of course, ChatGPT did come in handy for when we had small mistakes in the code

# %%
from random import randrange, random
from random import shuffle

# %%
# set up country list

cities = [
    "Paris", "Berlin", "London", "Madrid", "Rome", "Amsterdam", "Lisbon", "Prague", "Vienna", "Stockholm",
]

len(cities)
# Out:
# 10

# %%
def determine_coords(city_list, max_distance): # this just takes cities and assigns random coordinates to them, could also use real ones
    country_coords = {}
    for city in city_list:
        while len(country_coords) < len(city_list):
            coords = (randrange(0, max_distance), randrange(0, max_distance))
            if coords not in country_coords.values():
                country_coords[city] = coords
                break

    return country_coords

coords = determine_coords(cities, 20)
print(len(coords))

coords
# Out:
# 10
# {'Paris': (7, 17),
#  'Berlin': (7, 2),
#  'London': (8, 1),
#  'Madrid': (1, 8),
#  'Rome': (8, 19),
#  'Amsterdam': (10, 6),
#  'Lisbon': (18, 10),
#  'Prague': (17, 9),
#  'Vienna': (8, 14),
#  'Stockholm': (8, 2)}

# %%
# out of above cities, select N countries to construct initial population

def initial_cities(n_sol, n_countries, country_list):
    selected_cities = []  # list of n countries to permute
    while len(selected_cities) < n_sol:
        sublist_cities = []  # list of n countries to permute
        while len(sublist_cities) < n_countries:
            rand = randrange(0, len(country_list))
            selected_city = country_list[rand]
            if selected_city not in sublist_cities:
                sublist_cities.append(selected_city)
        if len(set(sublist_cities)) == n_countries:  # Ensure unique cities
            selected_cities.append(sublist_cities)

    return selected_cities

cities_selection = initial_cities(100, 10, cities)

# %%
def construct_pop_coords(solution_arr, coord_map):
    result_dict_list = []

    for subarray in solution_arr:
        subarray_dict = {city: coord_map.get(city, None) for city in subarray}
        result_dict_list.append(subarray_dict)

    return result_dict_list

solutions_coords = construct_pop_coords(cities_selection, coords)

solutions_coords[0]
# Out:
# {'Paris': (7, 17),
#  'Rome': (8, 19),
#  'Madrid': (1, 8),
#  'Vienna': (8, 14),
#  'Amsterdam': (10, 6),
#  'London': (8, 1),
#  'Prague': (17, 9),
#  'Stockholm': (8, 2),
#  'Berlin': (7, 2),
#  'Lisbon': (18, 10)}

# %%
from math import dist

# %%
def calc_total_dist(sol_coords): # this just calculates distances
    max_range = len(sol_coords[0]) - 1 # prevents from arriving at index 10, which does not exist
    total_dist_per_sol = []
    for sol_coord in sol_coords:
        solution_total_dist = 0
        coord_values = list(sol_coord.values())
        for i in range(max_range):
            city_1_coords = coord_values[i]
            city_2_coords = coord_values[i + 1]

            distance = dist(city_1_coords, city_2_coords)
            solution_total_dist += distance
            
        end_start_dist = dist(coord_values[max_range], coord_values[0]) # calculates distance from last city to first city
        solution_total_dist += end_start_dist

        total_dist_per_sol.append(solution_total_dist)
    
    return total_dist_per_sol

total_distances_per_sol = calc_total_dist(solutions_coords)

# %%
def assign_weights(distance_sum_list): # just creates some scores, bigger distances have lower scores
    score_list = []
    for distance_sum in distance_sum_list:
        score_list.append(1 / (1 + distance_sum))

    return score_list

weights = assign_weights(total_distances_per_sol)

len(weights)
# Out:
# 100

# %%
def probability_wheel(solutions, weights_list):
    total_score = sum(weights_list)
    probabilities = [x / total_score for x in weights_list] # gets proportion of each solution based on score (adds to 1)
    selection = []
    for i in range(len(solutions)):
        rand = random() # number between 0 and 1
        prob_sum = 0 # cumulative probability
        for idx, prob in enumerate(probabilities):
            prob_sum += prob # adds up to total
            if prob_sum > rand: # cutoff is exceeded
                selection.append(solutions[idx])
                break

    return selection

selected_solutions = probability_wheel(solutions_coords, weights)

# %%
# this one is quite lengthy, we are just mediocre at implementing ordered crossover
# what it does is it does a crossover ensuring there are never any duplicated in the newly created children

def crossover(solutions, cross_rate): # TO DO : IMPLEMENT CROSSOVER RATE
    parents = [(solutions[i], solutions[i + 1]) for i in range(0, len(solutions), 2)]
    cross_solutions = [] # store the newly crossovered solutions
    idxx = len(solutions[0])
    for parent1, parent2 in parents:
        sub_cross_solutions_c1 = {}
        sub_cross_solutions_c2 = {}

        p1_city = [city for city in parent1.keys()]
        p2_city = [city for city in parent2.keys()]
        p1_coords = [coord for coord in parent1.values()]
        p2_coords = [coord for coord in parent2.values()]

        p1_idx_list = [i for i in range(idxx)]
        p2_idx_list = [i for i in range(idxx)]

        shuffle(p1_idx_list)
        shuffle(p2_idx_list)

        start_point_idx = randrange(2, idxx - 3)
        end_point_idx = randrange(start_point_idx + 1, idxx - 2)

        c1_proto_init = [-1 for i in range(idxx)]
        c2_proto_init = [-1 for i in range(idxx)]

        c1_proto = c1_proto_init[:start_point_idx] + p1_idx_list[start_point_idx:end_point_idx] + c1_proto_init[end_point_idx:]
        c2_proto = c2_proto_init[:start_point_idx] + p2_idx_list[start_point_idx:end_point_idx] + c2_proto_init[end_point_idx:]

        for index, element in enumerate(c1_proto):
            if element == -1:
                for i in p2_idx_list:
                    if i not in c1_proto:
                        c1_proto[index] = i

        for index2, element2 in enumerate(c2_proto):
            if element2 == -1:
                for j in p1_idx_list:
                    if j not in c2_proto:
                        c2_proto[index2] = j

        for i in c1_proto:
            sub_cross_solutions_c1[p1_city[i]] = p1_coords[i]
            
        for j in c2_proto:
            sub_cross_solutions_c2[p2_city[j]] = p2_coords[j]
            
        cross_solutions.append(sub_cross_solutions_c1)
        cross_solutions.append(sub_cross_solutions_c2)

    return cross_solutions

crossover_results = crossover(selected_solutions, 0.1)

# %%
# this just interchanges some elements with a set rate

def mutate(solutions, mutate_rate):
    for idx, solution in enumerate(solutions):
        cities = [city for city in solution.keys()]
        coords = [coord for coord in solution.values()]
        for i, current_city in enumerate(cities):
            rand = random()
            rand_idx_2 = randrange(0, len(cities))
            if rand < mutate_rate:
                cities[i], cities[rand_idx_2] = cities[rand_idx_2], cities[i]
                coords[i], coords[rand_idx_2] = coords[rand_idx_2], coords[i]

        solutions[idx] = dict(zip(cities, coords))

    return solutions

mutate_test = mutate(crossover_results, 0.1)

mutate_test[0]
# Out:
# {'Lisbon': (18, 10),
#  'Madrid': (1, 8),
#  'Berlin': (7, 2),
#  'Prague': (17, 9),
#  'Rome': (8, 19),
#  'London': (8, 1),
#  'Amsterdam': (10, 6),
#  'Paris': (7, 17),
#  'Stockholm': (8, 2),
#  'Vienna': (8, 14)}

# %%
def genetic_algorithm(cities, max_distance, n_sol, n_cities, n_iterations, cross_rate, mutate_rate, verbose = False):
    coords = determine_coords(cities, max_distance)
    cities_selection = initial_cities(n_sol, n_cities, cities)
    solutions_coords = construct_pop_coords(cities_selection, coords)
    
    optimal_solution = None
    optimal_dist = 10000
    optimal_score = 0
    
    for iteration in range(n_iterations):
        total_distances = calc_total_dist(solutions_coords)
        weights = assign_weights(total_distances)
        selected_solutions = probability_wheel(solutions_coords, weights)

        crossover_results = crossover(selected_solutions, cross_rate)

        mutated_results = mutate(crossover_results, mutate_rate)

        total_distances_after_algo = calc_total_dist(mutated_results)
        weights_new_gen = assign_weights(total_distances_after_algo)

        best_dist = total_distances_after_algo[np.argmax(weights_new_gen)]
        best_sol = mutated_results[np.argmax(weights_new_gen)]

        if verbose:
            print(f"best solution : {best_sol} | total dist : {best_dist}")

        if best_dist < optimal_dist:
            optimal_dist = best_dist
            optimal_solution = best_sol

        solutions_coords = mutated_results

    print(f"shortest path found -> {optimal_solution}")
    print(f"distance traveled - > {optimal_dist}")

genetic_algorithm(cities = cities, max_distance = 20, n_sol = 100, n_cities = 10, n_iterations = 10000, cross_rate = 0.4, mutate_rate = 0.2, verbose = True)
# Out:
# best solution : {'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'London': (14, 9), 'Prague': (3, 12)} | total dist : 95.92672035538101
# best solution : {'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Madrid': (17, 2), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 86.92151060928394
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14)} | total dist : 91.22874970722575
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 82.60690460840912
# best solution : {'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14)} | total dist : 85.45523481337248
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'London': (14, 9), 'Rome': (13, 16), 'Prague': (3, 12)} | total dist : 90.9888945026154
# best solution : {'Rome': (13, 16), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 72.5503272110208
# best solution : {'Prague': (3, 12), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 88.48009463112969
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'London': (14, 9), 'Stockholm': (2, 14)} | total dist : 86.20841744752217
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9), 'Berlin': (17, 14), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16)} | total dist : 80.08409376529892
# best solution : {'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Paris': (0, 18), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12)} | total dist : 88.92967767303531
# best solution : {'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Rome': (13, 16)} | total dist : 88.9908316044762
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14)} | total dist : 81.62235332438956
# best solution : {'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 85.72892943793903
# best solution : {'Prague': (3, 12), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'London': (14, 9), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 75.81302769106134
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18)} | total dist : 77.27222270563644
# best solution : {'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Rome': (13, 16), 'Prague': (3, 12), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 87.86264395127641
# best solution : {'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Prague': (3, 12)} | total dist : 83.97753212660965
# best solution : {'Amsterdam': (4, 5), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 73.98067021987282
# best solution : {'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'London': (14, 9), 'Madrid': (17, 2)} | total dist : 85.15909209331836
# best solution : {'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16)} | total dist : 88.19570479677911
# best solution : {'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 80.44027350415703
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 84.433539038705
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 90.47349718110277
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 75.2805945160182
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Stockholm': (2, 14)} | total dist : 93.39736580250334
# best solution : {'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'London': (14, 9)} | total dist : 84.91021492886604
# best solution : {'Berlin': (17, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Rome': (13, 16), 'London': (14, 9), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 85.73199719007594
# best solution : {'Rome': (13, 16), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 72.60438586183574
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'London': (14, 9)} | total dist : 84.8158087069265
# best solution : {'Stockholm': (2, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14)} | total dist : 97.1040970683037
# best solution : {'Rome': (13, 16), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 89.70777486821851
# best solution : {'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5)} | total dist : 83.06400790163582
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Madrid': (17, 2), 'London': (14, 9), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 86.03089652619425
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Vienna': (0, 17)} | total dist : 87.61977644596556
# best solution : {'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 78.00529935178899
# best solution : {'Paris': (0, 18), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14)} | total dist : 85.18779140300046
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 89.85871460395651
# best solution : {'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 78.20510886774117
# best solution : {'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'London': (14, 9), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 73.42467667415258
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Rome': (13, 16)} | total dist : 96.86459589975075
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'Paris': (0, 18), 'Stockholm': (2, 14)} | total dist : 88.32816927212994
# best solution : {'Prague': (3, 12), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 85.82515914052706
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 91.3639704703264
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Paris': (0, 18), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 86.74294010799859
# best solution : {'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 84.28508534020278
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 78.4016227204044
# best solution : {'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Vienna': (0, 17)} | total dist : 83.45459716940424
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Paris': (0, 18), 'Amsterdam': (4, 5)} | total dist : 92.34020242491827
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 80.31068979049333
# best solution : {'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 88.46228456839349
# best solution : {'Prague': (3, 12), 'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'London': (14, 9), 'Madrid': (17, 2), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 89.37309478373525
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 82.86970502010604
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Rome': (13, 16)} | total dist : 89.30341703001017
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 72.4589929925236
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 88.89844974256097
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9)} | total dist : 84.99771954738331
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5)} | total dist : 91.1434440968376
# best solution : {'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17)} | total dist : 75.60656687718134
# best solution : {'Amsterdam': (4, 5), 'Paris': (0, 18), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 89.68244612730369
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 78.00529935178899
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 68.6096359665606
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Amsterdam': (4, 5)} | total dist : 91.86983934931274
# best solution : {'Madrid': (17, 2), 'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 84.59979568089265
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 77.05317029549914
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12)} | total dist : 63.83239630611362
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'London': (14, 9)} | total dist : 88.38854900877578
# best solution : {'Prague': (3, 12), 'Amsterdam': (4, 5), 'London': (14, 9), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 88.37737143801004
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'Amsterdam': (4, 5)} | total dist : 81.70884354932605
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5)} | total dist : 77.1597774233466
# best solution : {'Prague': (3, 12), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 85.91375627453007
# best solution : {'Paris': (0, 18), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 91.4970693718496
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Paris': (0, 18)} | total dist : 93.87664280099236
# best solution : {'Lisbon': (14, 0), 'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 87.6243991703953
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Vienna': (0, 17)} | total dist : 92.99434831906926
# best solution : {'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'London': (14, 9), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14)} | total dist : 80.39268396047046
# best solution : {'Prague': (3, 12), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 91.93384487403046
# best solution : {'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 92.00632542358872
# best solution : {'Vienna': (0, 17), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 95.36054596339119
# best solution : {'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Rome': (13, 16), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2)} | total dist : 87.4967974222598
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 76.06090234070459
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 81.30415705954567
# best solution : {'Rome': (13, 16), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 90.54860501151065
# best solution : {'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 82.12374937317213
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Stockholm': (2, 14)} | total dist : 80.11174052923747
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'London': (14, 9), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 75.56121086976921
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5)} | total dist : 75.62228630994511
# best solution : {'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 82.95112968929902
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'London': (14, 9)} | total dist : 90.91834666055256
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 76.92361454756195
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5)} | total dist : 81.9340096341724
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12)} | total dist : 82.95112968929904
# best solution : {'Vienna': (0, 17), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 85.70944261687669
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Stockholm': (2, 14)} | total dist : 80.96705616014434
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Lisbon': (14, 0)} | total dist : 93.03219517403474
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Berlin': (17, 14), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5), 'Stockholm': (2, 14)} | total dist : 85.3235102491524
# best solution : {'Vienna': (0, 17), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 85.93350396245013
# best solution : {'Madrid': (17, 2), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 80.555778236669
# best solution : {'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 88.43068446278937
# best solution : {'Stockholm': (2, 14), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 82.708779765406
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Lisbon': (14, 0)} | total dist : 81.21378059889608
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16)} | total dist : 84.79275670504651
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Vienna': (0, 17)} | total dist : 85.34984061918098
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 91.11866751730138
# best solution : {'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 80.12753895264815
# best solution : {'Madrid': (17, 2), 'London': (14, 9), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Berlin': (17, 14), 'Rome': (13, 16), 'Lisbon': (14, 0)} | total dist : 81.4868468703956
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5)} | total dist : 75.96109887593782
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9)} | total dist : 80.45001010659254
# best solution : {'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 76.83335603366493
# best solution : {'Prague': (3, 12), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 81.76696909379139
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 80.38579762090119
# best solution : {'Rome': (13, 16), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 83.1334161116934
# best solution : {'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Vienna': (0, 17)} | total dist : 95.90099315517166
# best solution : {'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 92.3402576780393
# best solution : {'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 83.44277233540505
# best solution : {'London': (14, 9), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 90.82090643324982
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Rome': (13, 16)} | total dist : 77.00941027135445
# best solution : {'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 79.54168160598495
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Lisbon': (14, 0)} | total dist : 78.11707921694192
# best solution : {'Rome': (13, 16), 'London': (14, 9), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 86.19051865123353
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 75.24258134204153
# best solution : {'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9)} | total dist : 79.45090503446085
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Vienna': (0, 17)} | total dist : 95.90099315517166
# best solution : {'Amsterdam': (4, 5), 'Prague': (3, 12), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 89.15188347830573
# best solution : {'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'London': (14, 9)} | total dist : 81.08477930568617
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 84.80082689607498
# best solution : {'Vienna': (0, 17), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 86.7572484382138
# best solution : {'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 81.37128395014847
# best solution : {'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16)} | total dist : 77.11244155446389
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 78.95669399366207
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Berlin': (17, 14)} | total dist : 90.16289665182428
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Vienna': (0, 17)} | total dist : 83.71384009939248
# best solution : {'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5)} | total dist : 80.95650242819967
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Prague': (3, 12), 'Stockholm': (2, 14)} | total dist : 77.33403093385965
# best solution : {'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 82.57295581171307
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12)} | total dist : 80.3788303022043
# best solution : {'London': (14, 9), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 87.27254366003359
# best solution : {'Stockholm': (2, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 87.4734934647384
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Paris': (0, 18), 'Stockholm': (2, 14)} | total dist : 82.35913188819197
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Paris': (0, 18)} | total dist : 85.11310617642803
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'London': (14, 9)} | total dist : 85.21410621693586
# best solution : {'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 86.38967718483671
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 90.10730337021306
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Rome': (13, 16), 'Berlin': (17, 14), 'Paris': (0, 18), 'Stockholm': (2, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 91.0605775251868
# best solution : {'Paris': (0, 18), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 81.8469757174233
# best solution : {'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Prague': (3, 12), 'London': (14, 9), 'Madrid': (17, 2)} | total dist : 86.73772503637241
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 79.5334859620228
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9), 'Prague': (3, 12)} | total dist : 75.91353872056673
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Prague': (3, 12)} | total dist : 85.29285327562629
# best solution : {'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Rome': (13, 16)} | total dist : 79.13349127797542
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 73.54549442918845
# best solution : {'Rome': (13, 16), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Berlin': (17, 14)} | total dist : 79.93431581876354
# best solution : {'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16)} | total dist : 79.37368186799566
# best solution : {'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'London': (14, 9), 'Rome': (13, 16)} | total dist : 85.60917407855396
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 84.9421953219869
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 86.74223331416025
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Prague': (3, 12)} | total dist : 69.53236735245228
# best solution : {'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'London': (14, 9), 'Rome': (13, 16), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 92.45045582589174
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 74.8485923700838
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 77.52148463102981
# best solution : {'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Madrid': (17, 2)} | total dist : 82.23659671799949
# best solution : {'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Vienna': (0, 17)} | total dist : 73.54549442918844
# best solution : {'Stockholm': (2, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 81.29341903900955
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2)} | total dist : 82.24066619751316
# best solution : {'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 77.80321523378747
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 96.46121752738767
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9)} | total dist : 72.1551870373241
# best solution : {'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 74.29007889423166
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Stockholm': (2, 14)} | total dist : 82.6322581811304
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5)} | total dist : 90.5648919422385
# best solution : {'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Paris': (0, 18)} | total dist : 86.69882114061207
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 83.05454877745294
# best solution : {'Rome': (13, 16), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 74.60218345353778
# best solution : {'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'London': (14, 9), 'Prague': (3, 12), 'Stockholm': (2, 14)} | total dist : 86.36407094274335
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5)} | total dist : 89.09914137899268
# best solution : {'Madrid': (17, 2), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Amsterdam': (4, 5), 'Lisbon': (14, 0)} | total dist : 84.5116794762996
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 81.88139160703668
# best solution : {'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Prague': (3, 12)} | total dist : 80.80145886278893
# best solution : {'Paris': (0, 18), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 80.60633581852902
# best solution : {'Lisbon': (14, 0), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2)} | total dist : 82.97757264304889
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 77.69809354251245
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Paris': (0, 18)} | total dist : 83.92234916085455
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Paris': (0, 18), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 90.1010173425411
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Madrid': (17, 2), 'London': (14, 9), 'Rome': (13, 16), 'Stockholm': (2, 14)} | total dist : 81.73949741771398
# best solution : {'Lisbon': (14, 0), 'Prague': (3, 12), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Madrid': (17, 2)} | total dist : 97.11012521696176
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 79.0815172864173
# best solution : {'Paris': (0, 18), 'Amsterdam': (4, 5), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14)} | total dist : 86.08242653822342
# best solution : {'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 69.71391794965683
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17)} | total dist : 80.05085206391527
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5)} | total dist : 72.05023802242992
# best solution : {'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 75.4400016940391
# best solution : {'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Rome': (13, 16), 'Paris': (0, 18), 'Stockholm': (2, 14)} | total dist : 82.94076462485248
# best solution : {'Vienna': (0, 17), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 86.8480115764637
# best solution : {'Paris': (0, 18), 'Berlin': (17, 14), 'Rome': (13, 16), 'Lisbon': (14, 0), 'London': (14, 9), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17)} | total dist : 86.21160619308216
# best solution : {'Prague': (3, 12), 'Amsterdam': (4, 5), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 69.41317975206036
# best solution : {'Amsterdam': (4, 5), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 86.94658772347289
# ...
# best solution : {'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Rome': (13, 16), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 78.95715191971615
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9)} | total dist : 76.28362257655756
# best solution : {'Prague': (3, 12), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Vienna': (0, 17), 'Paris': (0, 18), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Stockholm': (2, 14)} | total dist : 93.03835672175985
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 85.6123993570112
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Paris': (0, 18)} | total dist : 85.34868941323519
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5)} | total dist : 78.05334826263804
# best solution : {'Amsterdam': (4, 5), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2)} | total dist : 87.9462178380146
# best solution : {'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Rome': (13, 16)} | total dist : 74.37923165354752
# best solution : {'London': (14, 9), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14)} | total dist : 87.27718803395426
# best solution : {'Lisbon': (14, 0), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Madrid': (17, 2)} | total dist : 75.96109887593785
# best solution : {'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9)} | total dist : 82.05554939705017
# best solution : {'Paris': (0, 18), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Rome': (13, 16), 'Vienna': (0, 17)} | total dist : 90.00365213427219
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 89.53879250436064
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'London': (14, 9), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Rome': (13, 16)} | total dist : 87.80077682808583
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'London': (14, 9)} | total dist : 90.89835934353175
# best solution : {'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Rome': (13, 16)} | total dist : 79.96064216035825
# best solution : {'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18)} | total dist : 75.98302062731997
# best solution : {'London': (14, 9), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12)} | total dist : 81.25440695659113
# best solution : {'Rome': (13, 16), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14)} | total dist : 75.4293343359206
# best solution : {'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 77.60788363895543
# best solution : {'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Vienna': (0, 17), 'Rome': (13, 16)} | total dist : 85.07805332498108
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 78.84550137285275
# best solution : {'Paris': (0, 18), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Prague': (3, 12)} | total dist : 94.4091669187585
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14)} | total dist : 86.74610216161506
# best solution : {'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'London': (14, 9), 'Stockholm': (2, 14), 'Vienna': (0, 17)} | total dist : 82.68429151007268
# best solution : {'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'London': (14, 9), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16)} | total dist : 80.39268396047046
# best solution : {'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18)} | total dist : 84.23364634801516
# best solution : {'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Madrid': (17, 2)} | total dist : 85.93350396245015
# best solution : {'Rome': (13, 16), 'Paris': (0, 18), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17)} | total dist : 89.1747809382543
# best solution : {'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Madrid': (17, 2)} | total dist : 81.26299720274211
# best solution : {'Lisbon': (14, 0), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Madrid': (17, 2)} | total dist : 88.54363761089215
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 80.96705616014434
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Rome': (13, 16), 'London': (14, 9), 'Berlin': (17, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 75.29470029701935
# best solution : {'Lisbon': (14, 0), 'London': (14, 9), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2)} | total dist : 73.98067021987282
# best solution : {'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0)} | total dist : 82.708779765406
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5)} | total dist : 79.36569651390158
# best solution : {'Rome': (13, 16), 'Berlin': (17, 14), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 85.90897968830856
# best solution : {'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Stockholm': (2, 14), 'Prague': (3, 12)} | total dist : 88.24762600682165
# best solution : {'London': (14, 9), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14)} | total dist : 80.48934689424928
# best solution : {'Paris': (0, 18), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Vienna': (0, 17)} | total dist : 82.7252069877272
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 73.63126961771479
# best solution : {'Vienna': (0, 17), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Prague': (3, 12), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Rome': (13, 16)} | total dist : 86.05556368571975
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9)} | total dist : 78.7135424811663
# best solution : {'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14)} | total dist : 81.4507059057428
# best solution : {'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Prague': (3, 12), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 73.63126961771479
# best solution : {'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Amsterdam': (4, 5)} | total dist : 85.12071683011762
# best solution : {'Rome': (13, 16), 'Prague': (3, 12), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Berlin': (17, 14)} | total dist : 90.34594737124516
# best solution : {'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Prague': (3, 12), 'Paris': (0, 18), 'Stockholm': (2, 14), 'London': (14, 9), 'Rome': (13, 16), 'Berlin': (17, 14), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 80.98949735284577
# best solution : {'Rome': (13, 16), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Amsterdam': (4, 5)} | total dist : 80.67032188331684
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Rome': (13, 16), 'Madrid': (17, 2), 'Lisbon': (14, 0)} | total dist : 84.59755846298104
# best solution : {'Stockholm': (2, 14), 'Prague': (3, 12), 'Paris': (0, 18), 'Vienna': (0, 17), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 64.90697329636906
# best solution : {'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'London': (14, 9)} | total dist : 83.5577798719619
# best solution : {'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Paris': (0, 18), 'Rome': (13, 16), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'London': (14, 9), 'Berlin': (17, 14), 'Madrid': (17, 2)} | total dist : 89.65303831887005
# best solution : {'Stockholm': (2, 14), 'Vienna': (0, 17), 'Paris': (0, 18), 'Prague': (3, 12), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'Amsterdam': (4, 5)} | total dist : 75.22541155026309
# best solution : {'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17)} | total dist : 85.11564930869349
# best solution : {'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'Rome': (13, 16), 'Berlin': (17, 14), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12)} | total dist : 78.75310891835623
# best solution : {'Madrid': (17, 2), 'London': (14, 9), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14)} | total dist : 82.20325573120579
# best solution : {'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Lisbon': (14, 0), 'Amsterdam': (4, 5), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Madrid': (17, 2)} | total dist : 81.28550876162214
# best solution : {'Madrid': (17, 2), 'Lisbon': (14, 0), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Amsterdam': (4, 5)} | total dist : 67.68981395703908
# best solution : {'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Amsterdam': (4, 5), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Rome': (13, 16), 'Berlin': (17, 14), 'Prague': (3, 12)} | total dist : 77.17044478146508
# best solution : {'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Paris': (0, 18), 'Vienna': (0, 17), 'Prague': (3, 12), 'Lisbon': (14, 0), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2)} | total dist : 83.61991490336912
# best solution : {'Vienna': (0, 17), 'Amsterdam': (4, 5), 'Stockholm': (2, 14), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Prague': (3, 12), 'Paris': (0, 18)} | total dist : 86.56645723837197
# best solution : {'Prague': (3, 12), 'Vienna': (0, 17), 'Paris': (0, 18), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Rome': (13, 16), 'London': (14, 9), 'Madrid': (17, 2), 'Lisbon': (14, 0), 'Amsterdam': (4, 5)} | total dist : 67.31902369740226
# best solution : {'Amsterdam': (4, 5), 'London': (14, 9), 'Lisbon': (14, 0), 'Madrid': (17, 2), 'Prague': (3, 12), 'Stockholm': (2, 14), 'Berlin': (17, 14), 'Rome': (13, 16), 'Vienna': (0, 17), 'Paris': (0, 18)} | total dist : 89.92861067545837
# shortest path found -> {'Madrid': (17, 2), 'London': (14, 9), 'Berlin': (17, 14), 'Rome': (13, 16), 'Paris': (0, 18), 'Vienna': (0, 17), 'Stockholm': (2, 14), 'Prague': (3, 12), 'Amsterdam': (4, 5), 'Lisbon': (14, 0)}
# distance traveled - > 59.77038562146688
